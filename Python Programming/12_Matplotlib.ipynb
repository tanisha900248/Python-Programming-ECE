# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y = [1, 4, 5, 65, 76]
z = [1, 9, 27, 56, 176]
fig = plt.figure()
ax = plt.axes(projection = '3d')
ax.plot3D(z, y, x,marker="o")
plt.rcParams["grid.color"] = "grey"
